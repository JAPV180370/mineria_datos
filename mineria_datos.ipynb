# %% [markdown]
# <a href="https://colab.research.google.com/github/JAPV180370/mineria_datos/blob/main/mineria_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de Datos

# %% [markdown]
# ## Parcial 1

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# **Minería de Datos:**
#
# Es el proceso de buscar "tesoros" o patrones ocultos dentro de grandes cantidades de información que ya tenemos guardada.
#
# ---

# %% [markdown]
# ##### **Ciencia de Datos**

# %% [markdown]
# Es un campo mucho más amplio que abarca todo el ciclo de vida de la información. No solo se encarga de buscar patrones (minería), sino también de capturar los datos, limpiarlos porque vienen desordenados, analizarlos estadísticamente y, lo más importante, crear modelos para predecir el futuro.
#
# ---

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?

# %%
L = [1, 2, 3]
L.insert?

# %%
L?

# %%
def square(a):
  """Return the square of a."""
  return a ** 2

# %%
square?

# %%
square??

# %%
len??

# %%
L.<TAB>
# Out:
#   File "/tmp/ipython-input-3018186219.py", line 1
#     L.
#         ^
# SyntaxError: invalid syntax

# %%
L.cou<TAB>
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3190170265.py in <cell line: 0>()
# ----> 1 L.cou
#
# AttributeError: 'list' object has no attribute 'cou'

# %%
from itertools import co<TAB>
# Out:
#   File "/tmp/ipython-input-461150734.py", line 1
#     from itertools import co<TAB>
#                             ^
# SyntaxError: invalid syntax

# %%
import <TAB>
# Out:
#   File "/tmp/ipython-input-709411292.py", line 1
#     import <TAB>
#            ^
# SyntaxError: invalid syntax

# %%
*Warning?

# %%
str.*find*?
